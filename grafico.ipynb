# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5, 6]
y = [2, 4, 1, 8, 7, 5]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Etiquetas y título
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.title("Gráfico de Dispersión")

# Mostrar el gráfico
plt.show()
